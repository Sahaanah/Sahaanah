# %% [markdown]
# ## Importing the necessary Libraries

# %%
import os
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
#Fetching the current working directory
os.getcwd()
# Out:
# 'C:\\Users\\Sahaanah\\Desktop\\Internship\\Data set for project\\employee+promotion.zip (Unzipped Files)\\employee+promotion'

# %% [markdown]
# ## Reading the Dataset

# %%
df = pd.read_csv('C:\\Users\\Sahaanah\\Desktop\\Internship\\Data set for project\\employee+promotion.zip (Unzipped Files)\\employee+promotion\\train.csv')

# %%
test_data = pd.read_csv('C:\\Users\\Sahaanah\\Desktop\\Internship\\Data set for project\\employee+promotion.zip (Unzipped Files)\\employee+promotion\\test.csv')

# %%
df.head(10)
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
# 5        58896          Analytics   region_2        Bachelor's      m
# 6        20379         Operations  region_20        Bachelor's      f
# 7        16290         Operations  region_34  Master's & above      m
# 8        73202          Analytics  region_20        Bachelor's      m
# 9        28911  Sales & Marketing   region_1  Master's & above      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# ...

# %%
df.tail(10)
# Out:
#        employee_id         department     region         education gender  \
# 54798        40257  Sales & Marketing   region_2  Master's & above      f
# 54799        68093        Procurement   region_2  Master's & above      f
# 54800        39227                 HR  region_11        Bachelor's      m
# 54801        12431         Technology  region_26        Bachelor's      f
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 54798               other                2   40                   5.0
# ...

# %% [markdown]
# ## Data Pre-processing

# %%
df.drop("employee_id", axis = 1, inplace = True)

# %%
df.drop("region", axis = 1, inplace = True)

# %%
df.drop("recruitment_channel", axis = 1, inplace = True)

# %%
df.drop("department", axis = 1, inplace = True)

# %%
df.drop("age", axis = 1, inplace = True)

# %%
df.drop("education", axis = 1, inplace = True)

# %%
df
# Out:
#       gender  no_of_trainings  previous_year_rating  length_of_service  \
# 0          f                1                   5.0                  8
# 1          m                1                   5.0                  4
# 2          m                1                   3.0                  7
# 3          m                2                   1.0                 10
# 4          m                1                   3.0                  2
# ...      ...              ...                   ...                ...
# 48655      m                2                   1.0                  2
# 48656      m                1                   3.0                 17
# 48657      f                1                   2.0                  6
# 48658      m                1                   5.0                  3
# 48659      m                1                   1.0                  5
#
#        KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# ...

# %%
#Detecting all the empty values
df.isna().sum()
# Out:
# gender                  0
# no_of_trainings         0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
#Filling the empty values
df.fillna(0)
# Out:
#       gender  no_of_trainings  previous_year_rating  length_of_service  \
# 0          f                1                   5.0                  8
# 1          m                1                   5.0                  4
# 2          m                1                   3.0                  7
# 3          m                2                   1.0                 10
# 4          m                1                   3.0                  2
# ...      ...              ...                   ...                ...
# 48655      m                2                   1.0                  2
# 48656      m                1                   3.0                 17
# 48657      f                1                   2.0                  6
# 48658      m                1                   5.0                  3
# 48659      m                1                   1.0                  5
#
#        KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# ...

# %%
df.dropna(axis=0, inplace = True)

# %%
df
# Out:
#       gender  no_of_trainings  previous_year_rating  length_of_service  \
# 0          f                1                   5.0                  8
# 1          m                1                   5.0                  4
# 2          m                1                   3.0                  7
# 3          m                2                   1.0                 10
# 4          m                1                   3.0                  2
# ...      ...              ...                   ...                ...
# 48655      m                2                   1.0                  2
# 48656      m                1                   3.0                 17
# 48657      f                1                   2.0                  6
# 48658      m                1                   5.0                  3
# 48659      m                1                   1.0                  5
#
#        KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48660 entries, 0 to 48659
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gender                48660 non-null  object
#  1   no_of_trainings       48660 non-null  int64
#  2   previous_year_rating  48660 non-null  float64
#  3   length_of_service     48660 non-null  int64
#  4   KPIs_met >80%         48660 non-null  int64
#  5   awards_won?           48660 non-null  int64
#  6   avg_training_score    48660 non-null  int64
#  7   is_promoted           48660 non-null  int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 3.0+ MB

# %%
df.reset_index(drop = True, inplace=True)

# %%
df
# Out:
#       gender  no_of_trainings  previous_year_rating  length_of_service  \
# 0          f                1                   5.0                  8
# 1          m                1                   5.0                  4
# 2          m                1                   3.0                  7
# 3          m                2                   1.0                 10
# 4          m                1                   3.0                  2
# ...      ...              ...                   ...                ...
# 48655      m                2                   1.0                  2
# 48656      m                1                   3.0                 17
# 48657      f                1                   2.0                  6
# 48658      m                1                   5.0                  3
# 48659      m                1                   1.0                  5
#
#        KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# ...

# %%
df.isna().sum()
# Out:
# gender                  0
# no_of_trainings         0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
df.shape
# Out:
# (48660, 8)

# %%
df.describe()
# Out:
#        no_of_trainings  previous_year_rating  length_of_service  \
# count     48660.000000          48660.000000        48660.00000
# mean          1.251993              3.337526            6.31157
# std           0.604994              1.257922            4.20476
# min           1.000000              1.000000            1.00000
# 25%           1.000000              3.000000            3.00000
# 50%           1.000000              3.000000            5.00000
# 75%           1.000000              4.000000            8.00000
# max          10.000000              5.000000           37.00000
#
#        KPIs_met >80%  awards_won?  avg_training_score   is_promoted
# count   48660.000000  48660.00000        48660.000000  48660.000000
# mean        0.356473      0.02314           63.603309      0.086971
# std         0.478962      0.15035           13.273502      0.281795
# min         0.000000      0.00000           39.000000      0.000000
# ...

# %%
df.columns
# Out:
# Index(['gender', 'no_of_trainings', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
df.nunique()
# Out:
# gender                   2
# no_of_trainings         10
# previous_year_rating     5
# length_of_service       35
# KPIs_met >80%            2
# awards_won?              2
# avg_training_score      61
# is_promoted              2
# dtype: int64

# %%
df['previous_year_rating'].unique()
# Out:
# array([5., 3., 1., 4., 2.])

# %%
df['awards_won?'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ## Data Visualization

# %%
#Univariate, Bivariate and Multivariate Analysis
df.corr()
# Out:
#                       no_of_trainings  previous_year_rating  \
# no_of_trainings              1.000000             -0.064236
# previous_year_rating        -0.064236              1.000000
# length_of_service           -0.055440             -0.001252
# KPIs_met >80%               -0.046673              0.352434
# awards_won?                 -0.008528              0.027920
# avg_training_score           0.042033              0.070041
# is_promoted                 -0.025006              0.158715
#
#                       length_of_service  KPIs_met >80%  awards_won?  \
# no_of_trainings               -0.055440      -0.046673    -0.008528
# previous_year_rating          -0.001252       0.352434     0.027920
# length_of_service              1.000000      -0.089081    -0.043750
# KPIs_met >80%                 -0.089081       1.000000     0.095208
# awards_won?                   -0.043750       0.095208     1.000000
# avg_training_score            -0.047461       0.074114     0.073132
# ...

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.relplot(x = 'avg_training_score', y = 'length_of_service', hue = 'is_promoted', data = df)

# %% [markdown]
# From the above analysis, it is found that the emloyees with maximum training score are more likely to get promotion, irrespective of their length of service

# %%
sns.distplot(df['avg_training_score'])
# Out:
# C:\Users\Sahaanah\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='avg_training_score', ylabel='Density'>

# %% [markdown]
# From the above plot, it is infered that the average training score is approx.0.45

# %%
sns.distplot(df['length_of_service'])
# Out:
# C:\Users\Sahaanah\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='length_of_service', ylabel='Density'>

# %% [markdown]
# From the above plot, it is infered that the average length of service is approx.0.140

# %%
df.hist(bins=20, figsize=(15,8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_46156/3202148224.py in <module>
#       1 df.hist(bins=20, figsize=(15,8))
# ----> 2 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %% [markdown]
# From the above plots, it is infered that the 'average training score' and the 'length of service' are the parameters which
# greatly influence an employee's promotion

# %% [markdown]
# ## Feature Engineering

# %%
#Label Encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# Out:
# LabelEncoder()

# %%
df["gender"] = le.fit_transform(df["gender"])

# %%
cat_cols = ['no_of_trainings', 'previous_year_rating',
       'length_of_service', 'KPIs_met >80%', 'awards_won?',
       'avg_training_score', 'is_promoted']

# %%
for cols in cat_cols:
    le = LabelEncoder()
    df[cols] = le.fit_transform(df[cols])

# %%
df
# Out:
#        gender  no_of_trainings  previous_year_rating  length_of_service  \
# 0           0                0                     4                  7
# 1           1                0                     4                  3
# 2           1                0                     2                  6
# 3           1                1                     0                  9
# 4           1                0                     2                  1
# ...       ...              ...                   ...                ...
# 48655       1                1                     0                  1
# 48656       1                0                     2                 16
# 48657       0                0                     1                  5
# 48658       1                0                     4                  2
# 48659       1                0                     0                  4
#
#        KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# ...

# %%
# x, y split
X = df.drop("is_promoted", axis = 1)
y = df["is_promoted"]

# %%
# train, test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#        gender  no_of_trainings  previous_year_rating  length_of_service  \
# 47476       1                0                     4                 12
# 19512       1                0                     2                 16
# 11783       1                0                     4                  6
# 9905        1                0                     2                  4
# 19783       1                2                     4                  1
# ...       ...              ...                   ...                ...
# 11284       0                0                     2                 11
# 44732       1                0                     3                  8
# 38158       1                0                     3                  2
# 860         1                0                     2                  1
# 15795       1                0                     3                  8
#
#        KPIs_met >80%  awards_won?  avg_training_score
# ...

# %%
X_test
# Out:
#        gender  no_of_trainings  previous_year_rating  length_of_service  \
# 24742       1                0                     2                  7
# 25300       1                0                     3                  5
# 16214       1                1                     3                  4
# 41265       1                0                     2                  4
# 23413       1                0                     0                  7
# ...       ...              ...                   ...                ...
# 28406       1                2                     2                  3
# 40413       0                1                     2                  1
# 32617       1                2                     4                  5
# 32270       1                0                     3                  6
# 16424       1                1                     2                  3
#
#        KPIs_met >80%  awards_won?  avg_training_score
# ...

# %% [markdown]
# ## Prediction using Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 100, criterion = "gini")

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
#Model evaluation using various performance metrics 
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
confusion_matrix(y_test, y_pred, labels = [0, 1])
# Out:
# array([[12911,   368],
#        [ 1020,   299]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9049184819838334

# %%
recall_score(y_test, y_pred)
# Out:
# 0.2266868840030326

# %%
precision_score(y_test, y_pred)
# Out:
# 0.4482758620689655

# %%
f1_score(y_test, y_pred)
# Out:
# 0.3011077542799597

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     13279
#            1       0.45      0.24      0.31      1319
#
#     accuracy                           0.91     14598
#    macro avg       0.69      0.60      0.63     14598
# weighted avg       0.88      0.91      0.89     14598
